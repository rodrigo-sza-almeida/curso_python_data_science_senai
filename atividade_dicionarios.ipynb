# %%
contatos = {
    'João': '11999999999',
    'Ana': '21999999999',
    'Daniel': ['31999999999', '31999999998'],
    'Maria': '41999999999'
}
# Adiciconar
contatos.update(Joaquim='51999999999')
print(contatos)
# Remover 
contatos.pop('João')
print(contatos)
# Editar um contato
contatos['Daniel'][1] = '3199999997'
print(contatos)
for nome in contatos.keys():
    print(nome)
# Out:
# {'João': '11999999999', 'Ana': '21999999999', 'Daniel': ['31999999999', '31999999998'], 'Maria': '41999999999', 'Joaquim': '51999999999'}
# {'Ana': '21999999999', 'Daniel': ['31999999999', '31999999998'], 'Maria': '41999999999', 'Joaquim': '51999999999'}
# {'Ana': '21999999999', 'Daniel': ['31999999999', '3199999997'], 'Maria': '41999999999', 'Joaquim': '51999999999'}
# Ana
# Daniel
# Maria
# Joaquim
