# %% [markdown]
# # Aula 25/10/2025

# %% [markdown]
# ### Aula Itrodução ao Python
#
# **Características:**
# - Python é uma linguagem interpretada;
# - Forte e dinamicamente tipado;
# - Linguagem de alto nível
#
# <a href="https://docs.python.org/3/">Documentação Python</a>

# %%
print("Hello world!")
print(type("Hello world!"))
# Out:
# Hello world!
# <class 'str'>
