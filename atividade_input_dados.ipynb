# %%
nome = input("Nome: ").title()
idade = int(input("Idade: "))
cidade = input("Cidade: ").title()
estado = input("Estado: ").upper()

print()

print("--- Dados Cadastrais ---")
print(f"Nome: {nome}")
print(f"Idade: {idade}")
print(f"Cidade: {cidade}")
print(f"Estado: {estado}")
# Out:
# Nome:  joão
# Idade:  30
# Cidade:  são berbardo do campo
# Estado:  sp
# --- Dados Cadastrais ---
# Nome: João
# Idade: 30
# Cidade: São Berbardo Do Campo
# Estado: SP
